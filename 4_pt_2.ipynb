# %%
# !yolo task=detect mode=train model=yolov8s.pt data="/content/drive/My Drive/Butterfly/data.yaml" epochs=25 imgsz=800 plots=True
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !pip install -q yolov8

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="/content/drive/My Drive/Butterfly/data.yaml" epochs=25 imgsz=800 plots=True
# Out:
# Ultralytics YOLOv8.1.19 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import display, Image

# Correct the file path according to the file location in this environment
file_path_1 = '/content/runs/detect/train5/confusion_matrix.png'
file_path_2 = '/content/runs/detect/train5/confusion_matrix_normalized.png'
result = '/content/runs/detect/train5/val_batch0_pred.jpg'

# Display the image
display(Image(filename=file_path_1, width=800))
display(Image(filename=file_path_2, width=800))
display(Image(filename=result, width=800))
